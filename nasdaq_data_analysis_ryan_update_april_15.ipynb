# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# Set environment variables from the .env in the local environment
load_dotenv()
# Out:
# False

# %%
# Read in the NASDAQ data
ndx_df = pd.read_csv("data/NDX.csv", parse_dates=["Date"], date_format="%Y-%m-%d")
display(ndx_df.info())
display(ndx_df.head(1))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1258 non-null   datetime64[ns]
#  1   Open       1258 non-null   float64
#  2   High       1258 non-null   float64
#  3   Low        1258 non-null   float64
#  4   Close      1258 non-null   float64
#  5   Adj Close  1258 non-null   float64
#  6   Volume     1258 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 68.9 KB
# None
#         Date         Open         High          Low        Close    Adj Close  \
# 0 2019-04-11  7621.399902  7621.399902  7580.709961  7594.890137  7594.890137
#
#        Volume
# 0  1969480000

# %%
# Read in the 2019 US Economy Headlines
econ_2019_df = pd.read_csv("data/us_economy_headlines_2019.csv")
display(econ_2019_df.info())
display(econ_2019_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  230 non-null    object
#  1   headline  230 non-null    object
#  2   keywords  230 non-null    object
# dtypes: object(3)
# memory usage: 5.5+ KB
# None
#                    datetime  \
# 0  2019-08-17T10:27:08+0000
# 1  2019-01-17T00:15:01+0000
# 2  2019-08-01T17:44:59+0000
# 3  2019-10-10T09:00:14+0000
# 4  2019-03-15T19:34:32+0000
#
#                                             headline  \
# 0  Is a New Recession Imminent? Here’s How One Co...
# 1        In Small Towns, Shutdown Has Ripple Effects
# 2  Trump Escalates Fight Over Trade With the Chinese
# 3  A Steady Paycheck Is Good Medicine for Communi...
# 4                  Capitalism Needs Elizabeth Warren
#
#                                             keywords
# 0  [United States Economy,Recession and Depressio...
# ...

# %%
# Read in the 2020 US Economy Headlines
econ_2020_df = pd.read_csv("data/us_economy_headlines_2020.csv")
display(econ_2020_df.info())
display(econ_2020_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  400 non-null    object
#  1   headline  400 non-null    object
#  2   keywords  400 non-null    object
# dtypes: object(3)
# memory usage: 9.5+ KB
# None
#                    datetime  \
# 0  2020-03-24T15:53:24+0000
# 1  2020-11-14T14:33:29+0000
# 2  2020-11-16T10:00:22+0000
# 3  2020-08-03T19:40:23+0000
# 4  2020-04-09T13:07:59+0000
#
#                                             headline  \
# 0       Aid Deal Near as Trump Pushes to Ease Limits
# 1  Even Before Biden Takes Office, He Faces Quand...
# 2               Toxic Tussle With China Awaits Biden
# 3  Rescue of Kansas Company Tied To White House D...
# 4       ‘It’s Terrifying’: Millions More Out Of Work
#
#                                             keywords
# 0  [Coronavirus (2019-nCoV),Stimulus (Economic),U...
# ...

# %%
# Read in the 2021 US Economy Headlines
econ_2021_df = pd.read_csv("data/us_economy_headlines_2021.csv")
display(econ_2021_df.info())
display(econ_2021_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  367 non-null    object
#  1   headline  367 non-null    object
#  2   keywords  367 non-null    object
# dtypes: object(3)
# memory usage: 8.7+ KB
# None
#                    datetime                                          headline  \
# 0  2021-04-29T09:00:30+0000                    The Price Is Right, And Rising
# 1  2021-06-04T23:07:11+0000                Biden Says Benefits End In 90 Days
# 2  2021-06-18T16:38:06+0000   Unease on Wall Street Stretches to a Fourth Day
# 3  2021-06-30T07:00:11+0000          Fed Officials Less in Step As Costs Rise
# 4  2021-07-02T09:06:23+0000  Hiring Increases and Wages Jump as U.S. Rebounds
#
#                                             keywords
# 0  [United States Economy,Prices (Fares, Fees and...
# ...

# %%
# Read in the 2022 US Economy Headlines
econ_2022_df = pd.read_csv("data/us_economy_headlines_2022.csv")
display(econ_2022_df.info())
display(econ_2022_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 332 entries, 0 to 331
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  332 non-null    object
#  1   headline  332 non-null    object
#  2   keywords  332 non-null    object
# dtypes: object(3)
# memory usage: 7.9+ KB
# None
#                    datetime  \
# 0  2022-01-25T10:00:23+0000
# 1  2022-11-10T10:05:10+0000
# 2  2022-07-11T21:23:44+0000
# 3  2022-06-29T09:00:43+0000
# 4  2022-09-27T15:17:26+0000
#
#                                             headline  \
# 0         Timing of Fed Policy Pivot Nettles Critics
# 1  Inflation Starting to Taper In Positive Sign f...
# 2      As Prices Rise, Rental Market Is Hard to Exit
# 3  House Sales Have Cooled Significantly In Just ...
# 4  With Rents Quickly Rising,  How Are Landlords ...
#
#                                             keywords
# 0  [United States Economy,Inflation (Economics),I...
# ...

# %%
# Read in the 2023 US Economy Headlines
econ_2023_df = pd.read_csv("data/us_economy_headlines_2023.csv")
display(econ_2023_df.info())
display(econ_2023_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  263 non-null    object
#  1   headline  263 non-null    object
#  2   keywords  263 non-null    object
# dtypes: object(3)
# memory usage: 6.3+ KB
# None
#                    datetime  \
# 0  2023-03-22T22:56:22+0000
# 1  2023-03-16T16:31:12+0000
# 2  2023-01-06T08:00:13+0000
# 3  2023-01-20T10:00:38+0000
# 4  2023-07-17T18:20:03+0000
#
#                                             headline  \
# 0           Policymakers To Consider Tighter Rules
# 1                      Low Rates Are Over. Now What?
# 2      How Even a Soft Landing May Have Its Downside
# 3  New Orleans Port Positions Itself  For a Reord...
# 4   Jobs Have Roared Back, But Is Trend Sustainable?
#
#                                             keywords
# 0  [Regulation and Deregulation of Industry,Banki...
# ...

# %%
# Read in the 2024 US Economy Headlines
econ_2024_df = pd.read_csv("data/us_economy_headlines_2024.csv")
display(econ_2024_df.info())
display(econ_2024_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   datetime  55 non-null     object
#  1   headline  55 non-null     object
#  2   keywords  55 non-null     object
# dtypes: object(3)
# memory usage: 1.4+ KB
# None
#                    datetime  \
# 0  2024-03-05T10:36:33+0000
# 1  2024-03-20T09:06:22+0000
# 2  2024-02-05T10:01:45+0000
# 3  2024-01-19T21:11:26+0000
# 4  2024-04-05T09:35:34+0000
#
#                                             headline  \
# 0              Better Mood On Economy, Not for Biden
# 1    Federal Reserve Leaves Interest Rates Unchanged
# 2  Why Are Americans  Anxious in Spite Of a Good ...
# 3                Stock Market Climbs to a New Height
# 4  Labor Market Remains Hot As U.S. Adds  303,000...
#
#                                             keywords
# 0  [Polls and Public Opinion,United States Econom...
# ...

# %% [markdown]
# BEGINNING OF THE PLOTS AND ANALYSIS

# %%
#Import Dependencies for Graphing
import matplotlib.pyplot as plt
import scipy.stats as st
import datetime as dt
import numpy as np
from prophet import Prophet
from sklearn.linear_model import LinearRegression

# %%
#Creation of variable for 2019 Data.
ndx_2019 = ndx_df[(ndx_df["Date"] >= "2019-01-01") & (ndx_df["Date"] <= "2019-12-31")]

ndx_2019.head()
# Out:
#         Date         Open         High          Low        Close    Adj Close  \
# 0 2019-04-11  7621.399902  7621.399902  7580.709961  7594.890137  7594.890137
# 1 2019-04-12  7624.149902  7630.520020  7596.560059  7628.149902  7628.149902
# 2 2019-04-15  7630.600098  7636.799805  7578.540039  7629.120117  7629.120117
# 3 2019-04-16  7651.189941  7670.399902  7631.640137  7654.729980  7654.729980
# 4 2019-04-17  7705.319824  7715.069824  7659.850098  7680.720215  7680.720215
#
#        Volume
# 0  1969480000
# 1  1968900000
# 2  1827710000
# 3  2102740000
# 4  2317330000

# %%
#Plot of 2019 Low Closing Data
plt.plot(ndx_2019["Date"], ndx_2019["Low"], color="red")
plt.title("2019 End of Month NASDAQ Closing Prices")
plt.xlabel("Date")
plt.ylabel("Closing Price Low")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

#Plot of 2019 High Closing Data
plt.plot(ndx_2019["Date"], ndx_2019["High"], color="Green")
plt.title("2019 End of Month NASDAQ High Prices")
plt.xlabel("Date")
plt.ylabel("Closing Price High")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

#Correlation Plot of 2019 Date and Volume
plt.scatter(ndx_2019["Date"], ndx_2019["Volume"], color="Blue")
plt.title("2019 Date to Volume Correlation")
plt.xlabel("Date")
plt.ylabel("Volume (Billions)")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

#Correlation Practice, doesn't really tell you anything.
ndx_2019_correlation_construct = ["Date", "Open", "Close", "High", "Low", "Adj Close", "Volume"]
ndx_2019_correlation_calculation = ndx_2019[ndx_2019_correlation_construct].corr()
display(ndx_2019_correlation_calculation)
# Out:
#                Date      Open     Close      High       Low  Adj Close  \
# Date       1.000000  0.788079  0.782578  0.792234  0.779093   0.782578
# Open       0.788079  1.000000  0.988275  0.995210  0.993589   0.988275
# Close      0.782578  0.988275  1.000000  0.994152  0.995385   1.000000
# High       0.792234  0.995210  0.994152  1.000000  0.993521   0.994152
# Low        0.779093  0.993589  0.995385  0.993521  1.000000   0.995385
# Adj Close  0.782578  0.988275  1.000000  0.994152  0.995385   1.000000
# Volume    -0.035563 -0.005528 -0.027748  0.000504 -0.034123  -0.027748
#
#              Volume
# Date      -0.035563
# Open      -0.005528
# Close     -0.027748
# High       0.000504
# Low       -0.034123
# Adj Close -0.027748
# Volume     1.000000

# %%
#Creation of variable for 2020 - 2022 Data.
ndx_2020_2022 = ndx_df[(ndx_df["Date"] >= "2020 - 01- 01") & (ndx_df["Date"] <= "2022 - 12 - 31")]

ndx_2020_2022.head()
# Out:
#           Date         Open         High          Low        Close  \
# 183 2020-01-02  8802.219727  8873.629883  8786.900391  8872.219727
# 184 2020-01-03  8755.169922  8843.650391  8755.169922  8793.900391
# 185 2020-01-06  8713.889648  8849.980469  8713.889648  8848.519531
# 186 2020-01-07  8857.139648  8872.469727  8821.679688  8846.450195
# 187 2020-01-08  8845.450195  8953.549805  8834.940430  8912.370117
#
#        Adj Close      Volume
# 183  8872.219727  2862700000
# 184  8793.900391  2586520000
# 185  8848.519531  2810450000
# 186  8846.450195  2381740000
# 187  8912.370117  2472620000

# %%
#Plot of 2020 - 2022 Closing Data
plt.plot(ndx_2020_2022["Date"], ndx_2020_2022["Low"], color="red")
plt.title("2020 - 2022 End of Month NASDAQ Low Closing Prices")
plt.xlabel("Date")
plt.ylabel("Closing Price Low")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

#Plot of 2020 - 2022 High Closing Data
plt.plot(ndx_2020_2022["Date"], ndx_2020_2022["High"], color="Green")
plt.title("2020 - 2022 End of Month NASDAQ High Prices")
plt.xlabel("Date")
plt.ylabel("Closing Price High")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

#Correlation Plot of 2020 - 2022 Date and Volume
plt.scatter(ndx_2020_2022["Date"], ndx_2020_2022["Volume"], color="Blue")
plt.title("2020 - 2022 Date to Volume Correlation")
plt.xlabel("Date")
plt.ylabel("Volume (Billions)")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
#Creation of variable for 2022 - 2024 Data.
ndx_2022_2024 = ndx_df[(ndx_df["Date"] >= "2022 - 01- 01") & (ndx_df["Date"] <= "2024 - 12 - 31")]

ndx_2022_2024.head()
# Out:
#           Date          Open          High           Low         Close  \
# 688 2022-01-03  16395.509766  16504.140625  16306.639648  16501.769531
# 689 2022-01-04  16513.869141  16513.869141  16151.900391  16279.730469
# 690 2022-01-05  16190.549805  16249.230469  15763.839844  15771.780273
# 691 2022-01-06  15675.219727  15900.599609  15608.570313  15765.360352
# 692 2022-01-07  15774.129883  15835.000000  15526.799805  15592.190430
#
#         Adj Close      Volume
# 688  16501.769531  4429960000
# 689  16279.730469  5131110000
# 690  15771.780273  5031850000
# 691  15765.360352  4790820000
# 692  15592.190430  4238070000

# %%
#Plot of 2022 - 2024 Closing Data
plt.plot(ndx_2022_2024["Date"], ndx_2022_2024["Low"], color="red")
plt.title("2022 - 2024 End of Month NASDAQ Closing Prices")
plt.xlabel("Date")
plt.ylabel("Closing Price Low")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

#Plot of 2022 - 2024 High Data
plt.plot(ndx_2022_2024["Date"], ndx_2022_2024["High"], color="Green")
plt.title("2022 - 2024 End of Month NASDAQ High Prices")
plt.xlabel("Date")
plt.ylabel("Closing Price High")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

#Correlation Plot of 2022 - 2024 Date and Volume
plt.scatter(ndx_2022_2024["Date"], ndx_2022_2024["Volume"], color="Blue")
plt.title("2022 - 2024 Date to Volume Correlation")
plt.xlabel("Date")
plt.ylabel("Volume (Billions)")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# Descriptions of Years Data

# %%
display(ndx_2019.describe())

display(ndx_2020_2022.describe())

display(ndx_2022_2024.describe())
# Out:
#                                 Date         Open         High          Low  \
# count                            183   183.000000   183.000000   183.000000
# mean   2019-08-21 02:45:14.754098432  7857.842555  7896.460991  7814.594983
# min              2019-04-11 00:00:00  7056.180176  7126.430176  6936.680176
# 25%              2019-06-17 12:00:00  7632.314941  7680.189942  7584.494873
# 50%              2019-08-21 00:00:00  7806.069824  7842.979980  7756.109863
# 75%              2019-10-24 12:00:00  8001.089844  8030.235108  7963.585205
# max              2019-12-31 00:00:00  8805.860352  8811.099609  8749.860352
# std                              NaN   358.205589   350.270100   367.936156
#
#              Close    Adj Close        Volume
# count   183.000000   183.000000  1.830000e+02
# mean   7859.757012  7859.757012  2.087099e+09
# min    6978.020020  6978.020020  1.014530e+09
# 25%    7628.635009  7628.635009  1.885195e+09
# 50%    7814.740234  7814.740234  2.058090e+09
# ...

# %% [markdown]
# 2019 Months Breakdown

# %%
#January 2019
ndx_2019_jan = ndx_2019[(ndx_2019["Date"] >= "2019-01-01") & (ndx_2019["Date"] <= "2019-01-31")]

#February 2019
ndx_2019_feb = ndx_2019[(ndx_2019["Date"] >= "2019-02-01") & (ndx_2019["Date"] <= "2019-02-28")]

#March 2019
ndx_2019_mar = ndx_2019[(ndx_2019["Date"] >= "2019-03-01") & (ndx_2019["Date"] <= "2019-03-31")]

#April 2019
ndx_2019_apr = ndx_2019[(ndx_2019["Date"] >= "2019-04-01") & (ndx_2019["Date"] <= "2019-04-30")]

#May 2019
ndx_2019_may = ndx_2019[(ndx_2019["Date"] >= "2019-05-01") & (ndx_2019["Date"] <= "2019-05-31")]

#June 2019
ndx_2019_jun = ndx_2019[(ndx_2019["Date"] >= "2019-06-01") & (ndx_2019["Date"] <= "2019-06-30")]

#July 2019
ndx_2019_jul = ndx_2019[(ndx_2019["Date"] >= "2019-07-01") & (ndx_2019["Date"] <= "2019-07-31")]

#August 2019
ndx_2019_aug = ndx_2019[(ndx_2019["Date"] >= "2019-08-01") & (ndx_2019["Date"] <= "2019-08-31")]

#September 2019
ndx_2019_sep = ndx_2019[(ndx_2019["Date"] >= "2019-09-01") & (ndx_2019["Date"] <= "2019-09-30")]

#October 2019
ndx_2019_oct = ndx_2019[(ndx_2019["Date"] >= "2019-10-01") & (ndx_2019["Date"] <= "2019-10-31")]

#November 2019
ndx_2019_nov = ndx_2019[(ndx_2019["Date"] >= "2019-11-01") & (ndx_2019["Date"] <= "2019-11-30")]

#December 2019
ndx_2019_dec = ndx_2019[(ndx_2019["Date"] >= "2019-12-01") & (ndx_2019["Date"] <= "2019-12-31")]

# %% [markdown]
# Linear Regression of our Variables

# %% [markdown]
# Prophet Forecasting with our Variables
